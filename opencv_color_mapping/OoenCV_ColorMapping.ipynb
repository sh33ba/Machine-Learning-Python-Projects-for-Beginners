# %% [markdown]
# ### OPEN CV

# %% [markdown]
# #### COLOR MAPPING

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
cv.__version__
# Out:
# '4.1.0'

# %%
cv.__file__
# Out:
# 'C:\\Users\\hp\\Anaconda3\\lib\\site-packages\\cv2\\cv2.cp37-win_amd64.pyd'

# %%
np.__file__
# Out:
# 'C:\\Users\\hp\\Anaconda3\\lib\\site-packages\\numpy\\__init__.py'

# %%
np.__version__
# Out:
# '1.16.2'

# %%
plt.__file__
# Out:
# 'C:\\Users\\hp\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'

# %%
img=cv.imread("image8.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (340, 510, 3)

# %%
plt.imshow(img)

# %%
img_rgb=cv.cvtColor(img,cv.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)

# %%
img_g=cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
plt.imshow(img_g)

# %%
plt.imshow(img_g,cmap="gray")

# %%
b=img[:,:,:]

# %%
plt.imshow(b,cmap="gray")

# %%
i=img_g.copy()
i[:,:]=0

# %%
plt.imshow(i,cmap='gray')

# %%
img
# Out:
# array([[[60, 59, 45],
#         [70, 69, 55],
#         [75, 74, 60],
#         ...,
#         [48, 17, 14],
#         [23,  2,  0],
#         [28, 12,  0]],
#
#        [[67, 65, 54],
#         [74, 73, 59],
#         [76, 74, 63],
#         ...,
#         [44, 17,  7],
#         [44, 28, 12],
#         [53, 42, 22]],
#
#        [[73, 71, 61],
#         [79, 77, 66],
#         [78, 76, 66],
#         ...,
#         [43, 25,  2],
#         [32, 24,  0],
#         [33, 31,  0]],
#
#        ...,
#
#        [[10,  5,  2],
#         [10,  5,  2],
#         [10,  5,  2],
#         ...,
#         [13, 10,  2],
#         [11,  7,  2],
#         [13,  9,  4]],
#
#        [[11,  6,  3],
#         [11,  6,  3],
#         [11,  6,  3],
#         ...,
#         [13, 10,  2],
#         [11,  7,  2],
#         [13,  9,  4]],
#
#        [[12,  7,  4],
#         [12,  7,  4],
#         [12,  7,  4],
#         ...,
#         [13, 10,  2],
#         [11,  7,  2],
#         [13,  9,  4]]], dtype=uint8)

# %%
black=np.zeros((100,100),dtype='uint8')

# %%
plt.imshow(black,cmap='gray')

# %%
white=np.ones((100,100,3),dtype='uint8')*255

# %%
plt.imshow(white,cmap='gray')

# %%
red=np.zeros((100,100,3),dtype='uint8')
red[:,:,0]=255
plt.imshow(red,cmap='gray')

# %%
blue=np.zeros((100,100,3),dtype='uint8')
blue[:,:,2]=255
plt.imshow(blue,cmap='gray')

# %%
green=np.zeros((100,100,3),dtype='uint8')
green[:,:,1]=255
plt.imshow(green,cmap='gray')

# %%
yellow=np.zeros((100,100,3),dtype='uint8')
yellow[:,:]=[255,255,0]
plt.imshow(yellow,cmap='gray')

# %%
yellow=np.zeros((100,100,3),dtype='uint8')
yellow[:,:,0]=255
yellow[:,:,1]=255
plt.imshow(yellow,cmap='gray')

# %%
yellow=np.zeros((100,100,3),dtype='uint8')
yellow[:50,:]=[255,255,0]
yellow[50:,:]=[0,0,255]
plt.imshow(yellow)

# %%
yellow=np.zeros((100,100,3),dtype='uint8')
yellow[:50,:50]=[255,255,0]
yellow[50:,:50]=[0,0,255]
yellow[50:,50:]=[0,255,0]
yellow[:50,50:]=[255,0,0]
plt.imshow(yellow)

# %%
c=np.zeros((100,100,3),dtype='uint8')
for i in range(10,110,20):
    c[i-10:i,:]=[255,255,255]
    c[i:i+10,:]=[0,0,0]
plt.imshow(c)

# %%
c=np.zeros((100,100,3),dtype='uint8')
for j in range(10,110,20):
    for i in range(10,110,20):
        c[j-10:j,i-10:i]=[255,255,255]
        c[j:j+10,i:i+10]=[255,255,255]
plt.imshow(c)

# %%
c=np.zeros((20,100,3),dtype='uint8')
for i in range(10,111,20):
    c[:10,i-10:i]=[255,255,255]
    c[10:,i:i+10]=[255,255,255]
plt.imshow(c)

# %%
c=np.zeros((100,10,3),dtype='uint8')
for j in range(10,110,20):
    c[j-10:j,:10]=[]
plt.imshow(c)

# %%
import random
for i in range(5):
    print(random.randint(0,255))
# Out:
# 165
# 196
# 17
# 117
# 238

# %%
c=np.zeros((100,100,3),dtype='uint8')
for j in range(10,110,20):
    for i in range(10,110,20):
        c[j-10:j,i-10:i]=[200,50,200]
        c[j:j+10,i:i+10]=[20,200,200]
plt.imshow(c)

# %%
import random
c=np.zeros((10,100,3),dtype='uint8')
for i in range(10,111,20):
    for j in range(10,111,20):
        r_n=[]
        for k in range(6):
            [r_n+=random.randint(255)]
        c[:10,i-10:i]=[r_n50,150]
        c[:10,i:i+10]=[200,200,200]
plt.imshow(c)

# %%
import random
c=np.zeros((100,100,3),dtype='uint8')
for i in range(10,111,20):
    for j in range(10,111,20):
        r_n=[]
        for k in range(6):
            r_n+=[random.randint(0,255)]
        c[j-10:j,i-10:i]=[r_n[0],r_n[1],r_n[2]]
        c[j:j+10,i:i+10]=[r_n[3],r_n[4],r_n[5]]
plt.imshow(c)

# %%
import random
c=np.zeros((100,100,3),dtype='uint8')
for i in range(10,111,20):
    for j in range(10,111,20):
        r_n=[]
        for k in range(6):
            r_n+=[random.randint(0,255)]
        c[j-10:j,i-10:i]=[r_n[0],r_n[1],r_n[2]]
        c[i-10:i,j:j+10]=[r_n[3],r_n[4],r_n[5]]
plt.imshow(c)

# %%
import random
c=np.zeros((100,100,3),dtype='uint8')
for i in range(10,111,10):
    for j in range(10,111,10):
        r_n=[]
        for k in range(6):
            r_n+=[random.randint(0,255)]
        c[j-10:j,i-10:i]=[r_n[0],r_n[1],r_n[2]]
        c[i-10:i,j:j+10]=[r_n[3],r_n[4],r_n[5]]
plt.imshow(c,cmap='gray')
